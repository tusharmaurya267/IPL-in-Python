# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharmaurya267/IPL-in-Python/blob/main/IPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2099c4d1-6ac8-4a41-98fc-923342c677be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2099c4d1-6ac8-4a41-98fc-923342c677be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("IPL_Matches.csv")

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  29-05-2022   2022        Final
# 1  1312199  Ahmedabad  27-05-2022   2022  Qualifier 2
# 2  1312198    Kolkata  25-05-2022   2022   Eliminator
# 3  1312197    Kolkata  24-05-2022   2022  Qualifier 1
# 4  1304116     Mumbai  22-05-2022   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.shape
# Out:
# (950, 20)

# %% [markdown]
# Most number of "man of the match" awards

# %%
df["Player_of_Match"].value_counts()
# Out:
# AB de Villiers    25
# CH Gayle          22
# DA Warner         18
# RG Sharma         18
# MS Dhoni          17
#                   ..
# CR Brathwaite      1
# Mohsin Khan        1
# A Zampa            1
# BCJ Cutting        1
# MF Maharoof        1
# Name: Player_of_Match, Length: 262, dtype: int64

# %% [markdown]
# Top 10 Most number of "man of the match" awards

# %%
df["Player_of_Match"].value_counts()[0:10]
# Out:
# AB de Villiers    25
# CH Gayle          22
# DA Warner         18
# RG Sharma         18
# MS Dhoni          17
# YK Pathan         16
# SR Watson         16
# KA Pollard        14
# SK Raina          14
# V Kohli           14
# Name: Player_of_Match, dtype: int64

# %% [markdown]
# Top 5 players name with Most number of "man of the match" awards stored in an array

# %%
l1 = pd.array(df["Player_of_Match"].value_counts()[0:5].index)
l1

# %%
# Alternate
l1 = list(df["Player_of_Match"].value_counts()[0:5].keys())
l1
# Out:
# ['AB de Villiers', 'CH Gayle', 'DA Warner', 'RG Sharma', 'MS Dhoni']

# %% [markdown]
# Plotting the Top 5 players name with Most number of "man of the match" awards

# %%
plt.figure(figsize=(8,5)) 
plt.bar(l1,list(df['Player_of_Match'].value_counts() [0 : 5]), color="green") 
plt.show()

# %%
df["TossWinner"].value_counts()
# Out:
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Punjab Kings                     9
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: TossWinner, dtype: int64

# %% [markdown]
# Extracting matches where team won by Runs(Batting first)

# %%
batting_first  = df[df["WonBy"]=='Runs']
batting_first.shape
# Out:
# (423, 20)

# %%
batting_first.head()
# Out:
#          ID         City        Date Season MatchNumber  \
# 2   1312198      Kolkata  25-05-2022   2022  Eliminator
# 8   1304112  Navi Mumbai  18-05-2022   2022          66
# 9   1304111       Mumbai  17-05-2022   2022          65
# 10  1304110  Navi Mumbai  16-05-2022   2022          64
# 11  1304109       Mumbai  15-05-2022   2022          63
#
#                           Team1                  Team2  \
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# 8          Lucknow Super Giants  Kolkata Knight Riders
# 9           Sunrisers Hyderabad         Mumbai Indians
# 10               Delhi Capitals           Punjab Kings
# 11             Rajasthan Royals   Lucknow Super Giants
#
#                                  Venue            TossWinner TossDecision  \
# 2                Eden Gardens, Kolkata  Lucknow Super Giants        field
# 8   Dr DY Patil Sports Academy, Mumbai  Lucknow Super Giants          bat
# ...

# %% [markdown]
# Plotting Histogram for matches where team won by Runs(Batting first)

# %%
plt.figure(figsize=(4,4))
plt.hist(batting_first['Margin'])
plt.show()

# %% [markdown]
# Teams who won matches where team won by Runs(Batting first)

# %%
win_team = batting_first['WinningTeam'].value_counts()
win_team
# Out:
# Mumbai Indians                 66
# Chennai Super Kings            61
# Royal Challengers Bangalore    48
# Kolkata Knight Riders          45
# Kings XI Punjab                40
# Rajasthan Royals               37
# Sunrisers Hyderabad            36
# Delhi Daredevils               25
# Deccan Chargers                18
# Delhi Capitals                 13
# Punjab Kings                    7
# Lucknow Super Giants            7
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Gujarat Titans                  4
# Rising Pune Supergiants         2
# Kochi Tuskers Kerala            2
# Gujarat Lions                   1
# Name: WinningTeam, dtype: int64

# %% [markdown]
# Plotting barchart for Teams who won matches where team won by Runs(Batting first)

# %%
plt.figure(figsize = (8,4))
plt.bar(list(win_team[0:3].keys()) , list(win_team[0:3]) , color = ['blue' , 'yellow' , 'red'])
plt.show()

# %%
plt.figure(figsize = (8,4))
plt.pie( list(win_team) , labels = list(win_team.keys()) , autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# Extracting matches where team won by Wickets(Batting second)

# %%
batting_second  = df[df["WonBy"]=='Wickets']
batting_second.shape
# Out:
# (509, 20)

# %%
batting_second.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  29-05-2022   2022        Final
# 1  1312199  Ahmedabad  27-05-2022   2022  Qualifier 2
# 3  1312197    Kolkata  24-05-2022   2022  Qualifier 1
# 4  1304116     Mumbai  22-05-2022   2022           70
# 5  1304115     Mumbai  21-05-2022   2022           69
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
# 3             Rajasthan Royals    Gujarat Titans
# 4          Sunrisers Hyderabad      Punjab Kings
# 5               Delhi Capitals    Mumbai Indians
#
#                               Venue           TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad     Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad     Rajasthan Royals        field
# 3             Eden Gardens, Kolkata       Gujarat Titans        field
# ...

# %% [markdown]
# Plotting Histogram for matches where team won by Wickets(Batting second)

# %%
plt.figure(figsize=(4,4))
plt.hist(batting_second['Margin'])
plt.show()

# %% [markdown]
# Teams who won matches where team won by Wickets(Batting second)

# %%
win_team = batting_second['WinningTeam'].value_counts()
win_team
# Out:
# Kolkata Knight Riders          68
# Mumbai Indians                 63
# Chennai Super Kings            60
# Royal Challengers Bangalore    59
# Rajasthan Royals               57
# Kings XI Punjab                45
# Delhi Daredevils               42
# Sunrisers Hyderabad            38
# Delhi Capitals                 20
# Gujarat Lions                  12
# Deccan Chargers                11
# Gujarat Titans                  8
# Pune Warriors                   6
# Punjab Kings                    6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Lucknow Super Giants            2
# Name: WinningTeam, dtype: int64

# %% [markdown]
# Plotting barchart for Teams who won matches where team won by Wickets(batting_second)

# %%
plt.figure(figsize = (8,4))
plt.bar(list(win_team[0:3].keys()) , list(win_team[0:3]) , color = ['black' , 'blue' , 'yellow'])
plt.show()

# %%
plt.figure(figsize = (8,4))
plt.pie( list(win_team) , labels = list(win_team.keys()) , autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# Maximum number of season and cities

# %%
df['City'].value_counts()
# Out:
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Dharamsala          9
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: City, dtype: int64

# %%
df['Season'].value_counts()
# Out:
# 2013       76
# 2022       74
# 2012       74
# 2011       73
# 2021       60
# 2020/21    60
# 2019       60
# 2018       60
# 2016       60
# 2014       60
# 2009/10    60
# 2017       59
# 2015       59
# 2007/08    58
# 2009       57
# Name: Season, dtype: int64

# %%
df.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  29-05-2022   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
np.sum(df['TossWinner'] == df['WinningTeam'])
# Out:
# 489

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-550ec548-83f9-4547-9390-f8c5cf5f1ad4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-550ec548-83f9-4547-9390-f8c5cf5f1ad4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2 = pd.read_csv('IPL_Ball_by_Ball.csv')
df2
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
df2.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
match1 = df2[df2['ID']==1312200]

# %%
match1.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
match1.shape
# Out:
# (233, 17)

# %%
match1['BattingTeam'].value_counts()
# Out:
# Rajasthan Royals    120
# Gujarat Titans      113
# Name: BattingTeam, dtype: int64

# %%
RR = match1[match1['innings']==1]

# %%
RR['batsman_run'].value_counts()
# Out:
# 0    52
# 1    47
# 4    11
# 2     5
# 6     4
# 3     1
# Name: batsman_run, dtype: int64

# %%
RR['kind'].value_counts()
# Out:
# caught               6
# caught and bowled    1
# run out              1
# bowled               1
# Name: kind, dtype: int64

# %%
GT = match1[match1['innings']==2]

# %%
GT['batsman_run'].value_counts()
# Out:
# 0    51
# 1    36
# 2    12
# 4    10
# 6     4
# Name: batsman_run, dtype: int64

# %%
GT['kind'].value_counts()
# Out:
# caught    2
# bowled    1
# Name: kind, dtype: int64
